# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinay2408/demo/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("rapido_rides_data.csv")

# %%
df
# Out:
#          services        date      time ride_status  \
# 0            bike  2024-06-23  19:18:20   completed
# 1       bike lite  2024-07-06   2:42:20   completed
# 2          parcel  2024-07-19  17:55:20   completed
# 3            bike  2024-07-20   5:38:20   cancelled
# 4     cab economy  2024-07-12  19:36:20   completed
# ...           ...         ...       ...         ...
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 0             Banashankari 7th Stage              Richmond Road        99
# 1                  Indiranagar North              Sahakar Nagar        48
# 2        MG Road Mahatma Gandhi Road           Whitefield South       112
# ...

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.tail()
# Out:
#          services        date      time ride_status  \
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 9995  Brigade Road Mota Royal Arcade                Neelasandra       120
# 9996                     Frazer Town        MG Road Cubbon Park        71
# 9997      Brigade Road Church Street  HSR Layout Sector 5 North        71
# 9998           Rajajinagar 2nd Block         HSR Layout Central        26
# 9999                    Hebbal North       HSR Layout Sector 10        88
#
#                  ride_id  distance  ride_charge  misc_charge  total_fare  \
# 9995  RD8489738606219832     10.70          NaN          NaN         NaN
# ...

# %%
df.sample(5)
# Out:
#          services        date      time ride_status                    source  \
# 2521  cab economy  2024-07-02  21:26:20   completed                Nagarbhavi
# 5456    bike lite  2024-07-17  13:19:20   cancelled             Wilson Garden
# 1266  cab premium  2024-06-24  19:16:20   cancelled    Hebbal Byatarayanapura
# 5476   auto share  2024-07-04  13:41:20   cancelled  MG Road Symphony Theatre
# 1772  cab economy  2024-06-26  18:12:20   cancelled  Jayanagar 4th Block East
#
#                     destination  duration             ride_id  distance  \
# 2521                     Domlur        33  RD2877705382537729     14.71
# 5456  HSR Layout Sector 9 South        57  RD5273676171818768     10.85
# 1266          Marathahalli West       100  RD4189265735982503      2.63
# 5476      Koramangala 8th Block        15  RD8228456726027373      9.51
# 1772                     Ulsoor        25  RD1253375754117576     16.24
#
#       ride_charge  misc_charge  total_fare payment_method
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        10000 non-null  object
#  1   date            10000 non-null  object
#  2   time            10000 non-null  object
#  3   ride_status     10000 non-null  object
#  4   source          10000 non-null  object
#  5   destination     10000 non-null  object
#  6   duration        10000 non-null  int64
#  7   ride_id         10000 non-null  object
#  8   distance        10000 non-null  float64
#  9   ride_charge     4611 non-null   float64
#  10  misc_charge     4611 non-null   float64
#  11  total_fare      4611 non-null   float64
#  12  payment_method  4611 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.8+ KB

# %%
df['services']
# Out:
# 0              bike
# 1         bike lite
# 2            parcel
# 3              bike
# 4       cab economy
#            ...
# 9995           auto
# 9996     auto share
# 9997     auto share
# 9998    cab premium
# 9999    cab economy
# Name: services, Length: 10000, dtype: object

# %%
df.services
# Out:
# 0              bike
# 1         bike lite
# 2            parcel
# 3              bike
# 4       cab economy
#            ...
# 9995           auto
# 9996     auto share
# 9997     auto share
# 9998    cab premium
# 9999    cab economy
# Name: services, Length: 10000, dtype: object

# %%
lst = ['ride_status' , 'total_fare']
df[lst]
# Out:
#      ride_status  total_fare
# 0      completed       95.41
# 1      completed      432.45
# 2      completed      275.35
# 3      cancelled         NaN
# 4      completed      807.70
# ...          ...         ...
# 9995   cancelled         NaN
# 9996   completed      147.96
# 9997   cancelled         NaN
# 9998   cancelled         NaN
# 9999   completed      611.81
#
# [10000 rows x 2 columns]

# %%
df.describe()
# Out:
#            duration      distance  ride_charge  misc_charge   total_fare
# count  10000.000000  10000.000000  4611.000000  4611.000000  4611.000000
# mean      62.210000     25.563203   505.298315    25.206426   530.504741
# std       33.465001     14.199687   285.629503    14.271037   285.880226
# min        5.000000      1.010000    10.840000     0.020000    18.810000
# 25%       33.000000     13.210000   256.330000    12.855000   281.875000
# 50%       62.000000     25.645000   504.510000    25.530000   528.900000
# 75%       92.000000     37.832500   753.895000    37.270000   778.250000
# max      120.000000     49.990000   999.700000    49.990000  1044.290000

# %%
df.isnull().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 21556

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df_copy.isna().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# dtype: int64

# %%
df_copy.dropna(inplace=True)

# %%
df_copy.isna().sum()
# Out:
# services          0
# date              0
# time              0
# ride_status       0
# source            0
# destination       0
# duration          0
# ride_id           0
# distance          0
# ride_charge       0
# misc_charge       0
# total_fare        0
# payment_method    0
# dtype: int64

# %%
df_copy=df.copy()

# %%
df_copy.isna().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# dtype: int64

# %%
df_copy.fillna(0, inplace = True)

# %%
df_copy.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64         0.00
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df_copy=df.copy()

# %%
df_copy.head(6)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# ...

# %%
df_copy.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='object')

# %%
ride_charge_mean = df['ride_charge'].mean()
ride_charge_mean
# Out:
# 505.29831489915415

# %%
misc_charge_median = df_copy['misc_charge'].median()
misc_charge_median
# Out:
# 25.53

# %%
total_fare_median = df_copy['total_fare'].median()
total_fare_median
# Out:
# 528.9

# %%
payment_method_mode = df_copy.payment_method.mode()
payment_method_mode[0]
# Out:
# 'QR scan'

# %%
df_copy.ride_charge.fillna(ride_charge_mean, inplace=True)
df_copy.head(6)
# Out:
# <ipython-input-44-f9b1103661c3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy.ride_charge.fillna(ride_charge_mean, inplace=True)
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# ...

# %%
df_copy['misc_charge']=df_copy.misc_charge.fillna(misc_charge_median)

# %%
df_copy.head(6)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68    93.090000
# 1          Sahakar Nagar        48  RD4484661533610497     42.55   420.770000
# 2       Whitefield South       112  RD1526455182706880      5.85   247.900000
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64   505.298315
# ...

# %%
df_copy['total_fare']=df_copy.total_fare.fillna(total_fare_median)
df_copy.head(6)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68    93.090000
# 1          Sahakar Nagar        48  RD4484661533610497     42.55   420.770000
# 2       Whitefield South       112  RD1526455182706880      5.85   247.900000
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64   505.298315
# ...

# %%
df_copy['payment_method']=df_copy.payment_method.fillna(payment_method_mode[0])
df_copy.head(6)
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 5    bike lite  2024-07-07  20:01:20   cancelled        Indiranagar 7th Stage
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68    93.090000
# 1          Sahakar Nagar        48  RD4484661533610497     42.55   420.770000
# 2       Whitefield South       112  RD1526455182706880      5.85   247.900000
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64   505.298315
# ...

# %%
df_copy.isnull().sum()
# Out:
# services          0
# date              0
# time              0
# ride_status       0
# source            0
# destination       0
# duration          0
# ride_id           0
# distance          0
# ride_charge       0
# misc_charge       0
# total_fare        0
# payment_method    0
# dtype: int64

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        10000 non-null  object
#  1   date            10000 non-null  object
#  2   time            10000 non-null  object
#  3   ride_status     10000 non-null  object
#  4   source          10000 non-null  object
#  5   destination     10000 non-null  object
#  6   duration        10000 non-null  int64
#  7   ride_id         10000 non-null  object
#  8   distance        10000 non-null  float64
#  9   ride_charge     10000 non-null  float64
#  10  misc_charge     10000 non-null  float64
#  11  total_fare      10000 non-null  float64
#  12  payment_method  10000 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.8+ KB

# %%
df_copy.head(3)
# Out:
#     services        date      time ride_status                       source  \
# 0       bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1  bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2     parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
#
#         destination  duration             ride_id  distance  ride_charge  \
# 0     Richmond Road        99  RD8660319589404637     18.68        93.09
# 1     Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2  Whitefield South       112  RD1526455182706880      5.85       247.90
#
#    misc_charge  total_fare payment_method
# 0         2.32       95.41     Amazon Pay
# 1        11.68      432.45        QR scan
# 2        27.45      275.35           GPay

# %%
df_copy['datetime']=pd.to_datetime(df.date+" "+df.time)

# %%
df_copy.head(5)
# Out:
#       services ride_status                       source  \
# 0         bike   completed       Banashankari 7th Stage
# 1    bike lite   completed            Indiranagar North
# 2       parcel   completed  MG Road Mahatma Gandhi Road
# 3         bike   cancelled                     JP Nagar
# 4  cab economy   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68    93.090000
# 1          Sahakar Nagar        48  RD4484661533610497     42.55   420.770000
# 2       Whitefield South       112  RD1526455182706880      5.85   247.900000
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64   505.298315
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61   786.300000
#
#    misc_charge  total_fare payment_method            datetime
# 0         2.32       95.41     Amazon Pay 2024-06-23 19:18:20
# ...

# %%
df_copy.services.value_counts()
# Out:
# services
# auto           1479
# auto share     1473
# cab premium    1448
# bike lite      1424
# cab economy    1406
# bike           1388
# parcel         1382
# Name: count, dtype: int64

# %%
df_copy.head(2)
# Out:
#     services ride_status                  source    destination  duration  \
# 0       bike   completed  Banashankari 7th Stage  Richmond Road        99
# 1  bike lite   completed       Indiranagar North  Sahakar Nagar        48
#
#               ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0  RD8660319589404637     18.68        93.09         2.32       95.41
# 1  RD4484661533610497     42.55       420.77        11.68      432.45
#
#   payment_method            datetime
# 0     Amazon Pay 2024-06-23 19:18:20
# 1        QR scan 2024-07-06 02:42:20

# %%
df_copy['day_name']=df_copy.datetime.dt.day_name()

# %%
df_copy.head(3)
# Out:
#     services ride_status                       source       destination  \
# 0       bike   completed       Banashankari 7th Stage     Richmond Road
# 1  bike lite   completed            Indiranagar North     Sahakar Nagar
# 2     parcel   completed  MG Road Mahatma Gandhi Road  Whitefield South
#
#    duration             ride_id  distance  ride_charge  misc_charge  \
# 0        99  RD8660319589404637     18.68        93.09         2.32
# 1        48  RD4484661533610497     42.55       420.77        11.68
# 2       112  RD1526455182706880      5.85       247.90        27.45
#
#    total_fare payment_method            datetime  day_name
# 0       95.41     Amazon Pay 2024-06-23 19:18:20    Sunday
# 1      432.45        QR scan 2024-07-06 02:42:20  Saturday
# 2      275.35           GPay 2024-07-19 17:55:20    Friday

# %%
df_copy['day_name'].value_counts()
# Out:
# day_name
# Sunday       1643
# Tuesday      1627
# Monday       1601
# Saturday     1321
# Friday       1299
# Wednesday    1271
# Thursday     1238
# Name: count, dtype: int64

# %%
df_copy['hour']=df_copy.datetime.dt.hour

# %%
df_copy.head(3)
# Out:
#     services ride_status                       source       destination  \
# 0       bike   completed       Banashankari 7th Stage     Richmond Road
# 1  bike lite   completed            Indiranagar North     Sahakar Nagar
# 2     parcel   completed  MG Road Mahatma Gandhi Road  Whitefield South
#
#    duration             ride_id  distance  ride_charge  misc_charge  \
# 0        99  RD8660319589404637     18.68        93.09         2.32
# 1        48  RD4484661533610497     42.55       420.77        11.68
# 2       112  RD1526455182706880      5.85       247.90        27.45
#
#    total_fare payment_method            datetime  day_name  hour
# 0       95.41     Amazon Pay 2024-06-23 19:18:20    Sunday    19
# 1      432.45        QR scan 2024-07-06 02:42:20  Saturday     2
# 2      275.35           GPay 2024-07-19 17:55:20    Friday    17

# %%
df_copy.hour.value_counts()
# Out:
# hour
# 8     470
# 2     444
# 9     442
# 23    438
# 15    436
# 17    434
# 21    428
# 19    427
# 1     423
# 20    422
# 5     419
# 13    418
# 18    412
# 7     411
# 12    410
# 4     409
# 10    407
# 16    402
# 11    401
# 0     401
# 22    398
# 6     391
# 14    380
# 3     377
# Name: count, dtype: int64

# %%
df_copy['services']=df_copy['services'].str.lower()

# %%
df_bike = df_copy[df_copy['services'] == "bike"]
df_auto = df_copy[df_copy['services'] == "auto"]
df_cab = df_copy[df_copy['services'] == "cab premium"]

# %%
df_bike['distance'].sum()
# Out:
# 35857.95

# %%
df_auto['distance'].sum()
# Out:
# 37687.020000000004

# %%
df_copy['services'].unique()
# Out:
# array(['bike', 'bike lite', 'parcel', 'cab economy', 'auto',
#        'cab premium', 'auto share'], dtype=object)

# %%
df_cab['distance'].sum()
# Out:
# 37165.16

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data = df_copy, x ='services')
# Out:
# <Axes: xlabel='services', ylabel='count'>

# %%
df_copy.head()
# Out:
#       services ride_status                       source  \
# 0         bike   completed       Banashankari 7th Stage
# 1    bike lite   completed            Indiranagar North
# 2       parcel   completed  MG Road Mahatma Gandhi Road
# 3         bike   cancelled                     JP Nagar
# 4  cab economy   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68    93.090000
# 1          Sahakar Nagar        48  RD4484661533610497     42.55   420.770000
# 2       Whitefield South       112  RD1526455182706880      5.85   247.900000
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64   505.298315
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61   786.300000
#
#    misc_charge  total_fare payment_method            datetime  day_name  hour
# 0         2.32       95.41     Amazon Pay 2024-06-23 19:18:20    Sunday    19
# ...
